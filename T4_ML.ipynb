# %% [markdown]
# <a href="https://colab.research.google.com/github/mariacb24/Machine-learning/blob/main/T4_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [**BAGIAN 1**](https://docs.google.com/document/d/1_MRXQk50pRG0SD_XfbCT-Ubt8Nz4Okv5A4UuWhLczCw/edit?usp=sharing)

# %% [markdown]
# variabel target
# (median_house_price)=y

# %%
import pandas as pd
import numpy as np

from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

worksheet = gc.open('sample500').sheet1
rows = worksheet.get_all_values()
df = pd.DataFrame.from_records(rows[1:], columns=rows[0])

df
# Out:
#     longitude latitude housing_median_age total_rooms total_bedrooms  \
# 0     -118.04    34.17               52.0      1885.0          401.0
# 1     -118.48    34.07               37.0      4042.0          549.0
# 2     -119.85    36.82               15.0      1387.0          236.0
# 3     -122.01    38.26               12.0      4132.0          710.0
# 4     -117.08    32.74               35.0      1434.0          253.0
# ..        ...      ...                ...         ...            ...
# 495   -124.07    40.81               23.0      2103.0          411.0
# 496   -122.02    38.26               20.0      3899.0          763.0
# 497   -119.74     36.8               18.0     10862.0         2401.0
# 498   -118.24    34.01               30.0       405.0           86.0
# 499   -122.74    38.45               17.0      3064.0          588.0
#
#     population households median_income median_house_value ocean_proximity
# ...

# %% [markdown]
# ##**LONGITUDE**

# %%
df['longitude'] = pd.to_numeric(df['longitude'])
df['median_house_value'] = pd.to_numeric(df['median_house_value'])

x = df['longitude']
y = df['median_house_value']

n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

print(f"b0 (intercept): {b0}")
print(f"b1 (slope): {b1}")

# Persamaan regresi linier sederhana: y = b0 + b1*x
y_pred = b0 + b1 * x
sse = np.sum((y - y_pred)**2)
sst = np.sum((y - y_mean)**2)
r_squared = 1 - (sse / sst)

print(f"R-squared: {r_squared}")
# Out:
# b0 (intercept): -438285.09174928046
# b1 (slope): -5451.176883094852
# R-squared: 0.009022577470710558

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Longitude')
plt.ylabel('Median House Value')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# ## **LATITUDE**

# %%
df['latitude'] = pd.to_numeric(df['latitude'])
df['median_house_value'] = pd.to_numeric(df['median_house_value'])

x = df['latitude']
y = df['median_house_value']

n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

print(f"b0 (intercept): {b0}")
print(f"b1 (slope): {b1}")

# Persamaan regresi linier sederhana: y = b0 + b1*x
y_pred = b0 + b1 * x
sse = np.sum((y - y_pred)**2)
sst = np.sum((y - y_mean)**2)
r_squared = 1 - (sse / sst)

print(f"R-squared: {r_squared}")
# Out:
# b0 (intercept): 447407.5628691753
# b1 (slope): -6602.541689576582
# R-squared: 0.014823098714786598

# %%
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Latitude')
plt.ylabel('Median House Value')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# ## **HOUSING MEDIAN AGE**

# %%
df['housing_median_age'] = pd.to_numeric(df['housing_median_age'])
df['median_house_value'] = pd.to_numeric(df['median_house_value'])

x = df['housing_median_age']
y = df['median_house_value']

n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

print(f"b0 (intercept): {b0}")
print(f"b1 (slope): {b1}")

# Persamaan regresi linier sederhana: y = b0 + b1*x
y_pred = b0 + b1 * x
sse = np.sum((y - y_pred)**2)
sst = np.sum((y - y_mean)**2)
r_squared = 1 - (sse / sst)

print(f"R-squared: {r_squared}")
# Out:
# b0 (intercept): 165891.03922188142
# b1 (slope): 1698.2321852807254
# R-squared: 0.033664382713868624

# %%
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Housing Median Age')
plt.ylabel('Median House Value')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# ## **TOTAL ROOMS**

# %%
df['total_rooms'] = pd.to_numeric(df['total_rooms'])
df['median_house_value'] = pd.to_numeric(df['median_house_value'])

x = df['total_rooms']
y = df['median_house_value']

n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

print(f"b0 (intercept): {b0}")
print(f"b1 (slope): {b1}")

# Persamaan regresi linier sederhana: y = b0 + b1*x
y_pred = b0 + b1 * x
sse = np.sum((y - y_pred)**2)
sst = np.sum((y - y_mean)**2)
r_squared = 1 - (sse / sst)

print(f"R-squared: {r_squared}")
# Out:
# b0 (intercept): 189077.15588507475
# b1 (slope): 9.322873042986828
# R-squared: 0.020894914693083022

# %%
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Total Rooms')
plt.ylabel('Median House Value')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# ## **TOTAL BEDROOMS**

# %%
df['total_bedrooms'] = pd.to_numeric(df['total_bedrooms'])
df['median_house_value'] = pd.to_numeric(df['median_house_value'])

x = df['total_bedrooms']
y = df['median_house_value']

n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

print(f"b0 (intercept): {b0}")
print(f"b1 (slope): {b1}")

# Persamaan regresi linier sederhana: y = b0 + b1*x
y_pred = b0 + b1 * x
sse = np.sum((y - y_pred)**2)
sst = np.sum((y - y_mean)**2)
r_squared = 1 - (sse / sst)

print(f"R-squared: {r_squared}")
# Out:
# b0 (intercept): 203603.26633592215
# b1 (slope): 17.49342796981679
# R-squared: 0.014435351329263546

# %%
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Total Badrooms')
plt.ylabel('Median House Value')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# ## **POPULATION**

# %%
df['population'] = pd.to_numeric(df['population'])
df['median_house_value'] = pd.to_numeric(df['median_house_value'])

x = df['population']
y = df['median_house_value']

n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

print(f"b0 (intercept): {b0}")
print(f"b1 (slope): {b1}")

# Persamaan regresi linier sederhana: y = b0 + b1*x
y_pred = b0 + b1 * x
sse = np.sum((y - y_pred)**2)
sst = np.sum((y - y_mean)**2)
r_squared = 1 - (sse / sst)

print(f"R-squared: {r_squared}")
# Out:
# b0 (intercept): 219847.81209916182
# b1 (slope): -5.090368133098114
# R-squared: 0.0021571204777113273

# %%
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Population')
plt.ylabel('Median House Value')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# ## **HOUSEHOLDS**

# %%
df['households'] = pd.to_numeric(df['households'])
df['median_house_value'] = pd.to_numeric(df['median_house_value'])

x = df['households']
y = df['median_house_value']

n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

print(f"b0 (intercept): {b0}")
print(f"b1 (slope): {b1}")

# Persamaan regresi linier sederhana: y = b0 + b1*x
y_pred = b0 + b1 * x
sse = np.sum((y - y_pred)**2)
sst = np.sum((y - y_mean)**2)
r_squared = 1 - (sse / sst)

print(f"R-squared: {r_squared}")
# Out:
# b0 (intercept): 200334.44767800544
# b1 (slope): 25.61358795142861
# R-squared: 0.006467127440369924

# %%
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Households')
plt.ylabel('Median House Value')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()

# %% [markdown]
# ## **MEDIAN INCOME**

# %%
df['median_income'] = pd.to_numeric(df['median_income'])
df['median_house_value'] = pd.to_numeric(df['median_house_value'])

x = df['median_income']
y = df['median_house_value']

n = len(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

print(f"b0 (intercept): {b0}")
print(f"b1 (slope): {b1}")

# Persamaan regresi linier sederhana: y = b0 + b1*x
y_pred = b0 + b1 * x
sse = np.sum((y - y_pred)**2)
sst = np.sum((y - y_mean)**2)
r_squared = 1 - (sse / sst)

print(f"R-squared: {r_squared}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2,7575"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-debc4c0ebd1c> in <cell line: 1>()
# ----> 1 df['median_income'] = pd.to_numeric(df['median_income'])
#       2 df['median_house_value'] = pd.to_numeric(df['median_house_value'])
#       3
#       4 x = df['median_income']
#       5 y = df['median_house_value']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     230         coerce_numeric = errors not in ("ignore", "raise")
#     231         try:
# ...

# %% [markdown]
# # **BAGIAN 2**

# %%
from google.colab import auth
auth.authenticate_user()
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

worksheet = gc.open('Data_ML_2').sheet1
rows = worksheet.get_all_values()
df = pd.DataFrame.from_records(rows[1:], columns=rows[0])

df
# Out:
#   Size (sq ft) Age (years) Price ($)
# 0         1500          10    300000
# 1         1600           8    320000
# 2         1700           5    340000
# 3         1800           2    360000
# 4         1900           1    380000
